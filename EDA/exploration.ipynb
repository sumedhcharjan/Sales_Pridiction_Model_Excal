# %%
# Importing core libraries for data exploration and visualization
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

warnings.filterwarnings('ignore')
sns.set_theme(style='ticks')

# Loading the SuperKart dataset
df = pd.read_csv('../dataset/dataset.csv')

# %%
pd.crosstab(df["Store_Type"], df["Store_Size"])
pd.crosstab(df["Store_Type"], df["Store_Location_City_Type"])
pd.crosstab(df["Store_Type"], df["Store_Establishment_Year"])
# Out:
# Store_Establishment_Year  1987  1998  1999  2009
# Store_Type
# Departmental Store           0     0  1349     0
# Food Mart                    0  1152     0     0
# Supermarket Type1         1586     0     0     0
# Supermarket Type2            0     0     0  4676

# %% [markdown]
# remove store id
# remove store establisment year
# add store age
# dont remove skewness
# remove unique identifier projuct id
